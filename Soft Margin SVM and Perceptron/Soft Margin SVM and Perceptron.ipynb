# %% [markdown]
# # Machine Learning in Bioinformatics

# %% [markdown]
# # Homework 2:
#  !!! If you don't fill these fields, your homework does not count !!!<by/>
#  #### first name and last name : Sana Ayromlou
#  #### student number : 96101284

# %% [markdown]
# You can run cells by hitting `Shift` + `Enter` or `ctrl` + `Enter`. <br/>
# We highly recommend you to read each line of code carefully and try to understand what it exactly does. <br/>
# Just alter the parts that is between green comments and specified for you. Please do not change other parts.

# %%
# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# %% [markdown]
# # Problem 1. soft margin SVM
# ### about the Data:<br/>
# The purpose of this project is to classify tumors into malignant or benign. The following dataset is constructed based on images of tumors. Features are computed from a digitized image of a fine needle aspirate (FNA) of a breast mass.
# For more details about the features of this dataset you can visit this link:
# https://scikit-learn.org/stable/datasets/index.html#breast-cancer-dataset<br/>
# This dataset contains 30 features and 1 label that is called target. We should find a proper hyperplane that separates malignant and benign samples.
# The original dataset labels is 0 and 1 and in the following code boxes we change it to -1 and 1.

# %%
cancer = load_breast_cancer()
df = pd.DataFrame(np.c_[cancer["data"], cancer["target"]], columns = np.append(cancer["feature_names"],["target"]))
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890     0.0
# 1          0.2750                  0.08902     0.0
# 2          0.3613                  0.08758     0.0
# 3          0.6638                  0.17300     0.0
# 4          0.2364                  0.07678     0.0
#
# [5 rows x 31 columns]

# %%
cancer.target = np.where(cancer.target==0, -1, cancer.target) 
X_train ,X_test ,X_val ,y_train ,y_test ,y_val = None ,None ,None ,None ,None ,None
################################################################################
# TODO: using train_test_split package, split your data into 3 numpy array     #
# called X_train, X_test, and X_val and also split the corresponding labels as #
# y_train, y_test, and y_val. After spliting, the ratio of your data should be # 
# approximately like this:                                                     #
#  Train : 72%     test : 20%       validation : 8%                            #
################################################################################
y = cancer.target
df = df.drop(["target"], axis=1)
X = df.values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1)

################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
print((X_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_train.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_test.shape[0]/cancer.data.shape[0]) * 100, "%")
print((X_val.shape[0]/cancer.data.shape[0]) * 100, "%")
print((y_val.shape[0]/cancer.data.shape[0]) * 100, "%")
# Out:
# 71.8804920913884 %
# 71.8804920913884 %
# 20.035149384885763 %
# 20.035149384885763 %
# 8.084358523725834 %
# 8.084358523725834 %

# %% [markdown]
# ### soft margin SVM optimization:<br/>
# We add 1 at the beginning of each Xs data (X_train, X_val , ...) and then the bias will be calculated implicitly.
# Then you should minimize the following SVM loss function (using gradient descent) with changing parameters of model.<br>
# In this notation:
# \begin{equation}
# x_i , y_i
# \end{equation}
# refers to feature vector of the sample and the label of our training data<br>
# and this is SVM loss function:
#
# \begin{equation}
# \large
# J(W) = \frac{1}{N} \sum_{i=1}^{N}{L^{(i)}} + \frac{\lambda}{2} ||W||^2\\
# \large
# L^{(i)} ={max(0, 1 - y_i(w^{T}x_i)})
# \;\\
# \end{equation}

# %%
# >>>>>WARNING: RUN THIS CELL ONLY ONCE!<<<<<

# adding 1s to the end of feature vectors to be multiplied by bias term of weights
X_val = np.insert(X_val, 0, 1, axis=1)
X_train = np.insert(X_train, 0, 1, axis=1)
X_test = np.insert(X_test, 0, 1, axis=1)
print(X_train.shape)  
print(X_val.shape)  
print(X_test.shape)
# Out:
# (409, 31)
# (46, 31)
# (114, 31)

# %% [markdown]
# Complete the following functions in SVM class. In the part that you should compute loss function of this class, you are not allowed to use "for" loop.

# %%
class SVM:
    def __init__(self, n_features: int, std: float):
        """
        n_features: number of features in (or the dimension of) each instance
        std: standard deviation used in the initialization of the weights of svm
        """
        self.n_features = n_features
        ################################################################################
        # TODO: Initialize the weights of svm using random normal distribution with    #
        # standard deviation equals to std.                                            #
        ################################################################################

        mu, sigma = 0, 0.1 # mean and standard deviation
        self.W = np.random.normal(0, std , n_features)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):
        """
        X: training instances as a 2d-array with shape (num_train, n_features)
        y: labels corresponsing to the given training instances as a 1d-array with shape (num_train,)
        reg_coeff: L2-regularization coefficient
        """
        loss = 0.0
        
        #################################################################################
        # TODO: Compute the hinge loss specified in the notebook and save it in the loss#                                                   # loss variable.                                                               #
        # NOTE: YOU ARE NOT ALLOWED TO USE FOR LOOPS!                                   #
        # Don't forget L2-regularization term in your implementation!                   #
        #################################################################################
        
        loss = 0.0
        scores = np.dot(X, self.W)
        scores = np.multiply(scores,y)
        loss = sum(np.maximum(0, 1-scores))/len(scores)
        loss += 0.5*reg_coeff*np.dot(np.transpose(self.W),self.W)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return loss
        
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float , reg_coeff: float):
        """
        Updates the weights of the svm using the gradient of computed loss with respect to the weights. 
        learning_rate: learning rate that will be used in gradient descent to update the weights
        """
        ################################################################################
        # TODO: Compute the gradient of loss computed above w.r.t the svm weights.     #
        # and then update self.w with the computed gradient.                           #
        # (don't forget learning rate and reg_coeff in update rule)                    #
        # Don't forget L2-regularization term in your implementation!                  #
        ################################################################################
        
        
        dl = reg_coeff * self.W
        for i in range(len(y)):
            if 1 - np.dot(X[i],self.W)*y[i] > 0:
                dl -= y[i]*X[i]/(X.shape[0])
        self.W -= learning_rate*dl

        
        
        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
    def predict(self, X):
        """
        X: Numpy 2d-array of instances
        """
        y_pred = None
        ################################################################################
        # TODO: predict the labels for the instances in X and save them in y_pred.     #                                      #
        ################################################################################

        y_pred = []
        for i in range(len(X)):
            r = np.dot(X[i],self.W)
            if r > 0:
                y_pred.append(1)
            else:
                y_pred.append(-1)

        ################################################################################
        #                                 END OF YOUR CODE                             #
        ################################################################################
        return y_pred

# %% [markdown]
# This cell contains your hyper parameters:

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8

# %% [markdown]
# In this cell using your SVM class, we want to train our model for cancer data:<br/>
# In every iteration you should see your training loss decrease.

# %%
from sklearn.metrics import accuracy_score
model = SVM(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.018717, val acc 58.70%
# iteration 100, loss 0.989426, val acc 41.30%
# iteration 200, loss 0.961130, val acc 41.30%
# iteration 300, loss 0.946826, val acc 41.30%
# iteration 400, loss 0.941246, val acc 41.30%
# iteration 500, loss 0.939185, val acc 41.30%
# iteration 600, loss 0.937522, val acc 41.30%
# iteration 700, loss 0.935865, val acc 41.30%
# iteration 800, loss 0.934209, val acc 41.30%
# iteration 900, loss 0.932553, val acc 41.30%
# iteration 1000, loss 0.930897, val acc 41.30%
# iteration 1100, loss 0.929241, val acc 41.30%
# iteration 1200, loss 0.927586, val acc 41.30%
# iteration 1300, loss 0.925939, val acc 41.30%
# iteration 1400, loss 0.924291, val acc 41.30%
# iteration 1500, loss 0.922644, val acc 41.30%
# iteration 1600, loss 0.920997, val acc 41.30%
# iteration 1700, loss 0.919350, val acc 41.30%
# iteration 1800, loss 0.917710, val acc 41.30%
# iteration 1900, loss 0.916124, val acc 41.30%
# iteration 2000, loss 0.914583, val acc 41.30%
# iteration 2100, loss 0.913045, val acc 41.30%
# iteration 2200, loss 0.911507, val acc 41.30%
# iteration 2300, loss 0.909970, val acc 41.30%
# iteration 2400, loss 0.908432, val acc 41.30%
# iteration 2500, loss 0.906894, val acc 41.30%
# iteration 2600, loss 0.905357, val acc 41.30%
# iteration 2700, loss 0.903829, val acc 41.30%
# iteration 2800, loss 0.902340, val acc 41.30%
# iteration 2900, loss 0.900851, val acc 41.30%
# iteration 3000, loss 0.899362, val acc 41.30%
# iteration 3100, loss 0.897902, val acc 41.30%
# iteration 3200, loss 0.896453, val acc 41.30%
# iteration 3300, loss 0.895005, val acc 41.30%
# iteration 3400, loss 0.893556, val acc 41.30%
# iteration 3500, loss 0.892107, val acc 41.30%
# iteration 3600, loss 0.890659, val acc 41.30%
# iteration 3700, loss 0.889210, val acc 41.30%
# iteration 3800, loss 0.887762, val acc 41.30%
# iteration 3900, loss 0.886313, val acc 41.30%
# iteration 4000, loss 0.884869, val acc 41.30%
# iteration 4100, loss 0.883426, val acc 41.30%
# iteration 4200, loss 0.881983, val acc 41.30%
# iteration 4300, loss 0.880541, val acc 41.30%
# iteration 4400, loss 0.879098, val acc 41.30%
# iteration 4500, loss 0.877655, val acc 41.30%
# iteration 4600, loss 0.876213, val acc 41.30%
# iteration 4700, loss 0.874778, val acc 41.30%
# iteration 4800, loss 0.873353, val acc 41.30%
# iteration 4900, loss 0.871928, val acc 41.30%
# iteration 5000, loss 0.870503, val acc 41.30%
# iteration 5100, loss 0.869079, val acc 41.30%
# iteration 5200, loss 0.867654, val acc 41.30%
# iteration 5300, loss 0.866229, val acc 41.30%
# iteration 5400, loss 0.864805, val acc 41.30%
# iteration 5500, loss 0.863380, val acc 41.30%
# iteration 5600, loss 0.861956, val acc 41.30%
# iteration 5700, loss 0.860532, val acc 41.30%
# iteration 5800, loss 0.859107, val acc 41.30%
# iteration 5900, loss 0.857683, val acc 41.30%
# iteration 6000, loss 0.856259, val acc 41.30%
# iteration 6100, loss 0.854835, val acc 41.30%
# iteration 6200, loss 0.853410, val acc 41.30%
# iteration 6300, loss 0.851986, val acc 41.30%
# iteration 6400, loss 0.850562, val acc 41.30%
# iteration 6500, loss 0.849138, val acc 41.30%
# iteration 6600, loss 0.847715, val acc 41.30%
# iteration 6700, loss 0.846296, val acc 41.30%
# iteration 6800, loss 0.844880, val acc 41.30%
# iteration 6900, loss 0.843465, val acc 43.48%
# iteration 7000, loss 0.842049, val acc 43.48%
# iteration 7100, loss 0.840634, val acc 43.48%
# iteration 7200, loss 0.839218, val acc 43.48%
# iteration 7300, loss 0.837803, val acc 45.65%
# iteration 7400, loss 0.836388, val acc 47.83%
# iteration 7500, loss 0.834972, val acc 50.00%
# iteration 7600, loss 0.833557, val acc 50.00%
# iteration 7700, loss 0.832142, val acc 50.00%
# iteration 7800, loss 0.830727, val acc 50.00%
# iteration 7900, loss 0.829312, val acc 56.52%
# iteration 8000, loss 0.827897, val acc 56.52%
# iteration 8100, loss 0.826482, val acc 60.87%
# iteration 8200, loss 0.825067, val acc 63.04%
# iteration 8300, loss 0.823655, val acc 63.04%
# iteration 8400, loss 0.822245, val acc 65.22%
# iteration 8500, loss 0.820835, val acc 65.22%
# iteration 8600, loss 0.819426, val acc 65.22%
# iteration 8700, loss 0.818016, val acc 65.22%
# iteration 8800, loss 0.816607, val acc 65.22%
# iteration 8900, loss 0.815197, val acc 71.74%
# iteration 9000, loss 0.813788, val acc 71.74%
# iteration 9100, loss 0.812379, val acc 71.74%
# iteration 9200, loss 0.810970, val acc 71.74%
# iteration 9300, loss 0.809560, val acc 71.74%
# iteration 9400, loss 0.808151, val acc 71.74%
# iteration 9500, loss 0.806742, val acc 71.74%
# iteration 9600, loss 0.805333, val acc 71.74%
# iteration 9700, loss 0.803924, val acc 69.57%
# iteration 9800, loss 0.802515, val acc 71.74%
# iteration 9900, loss 0.801106, val acc 71.74%
# iteration 10000, loss 0.799698, val acc 69.57%
# iteration 10100, loss 0.798289, val acc 69.57%
# iteration 10200, loss 0.796880, val acc 69.57%
# iteration 10300, loss 0.795472, val acc 69.57%
# iteration 10400, loss 0.794063, val acc 69.57%
# iteration 10500, loss 0.792654, val acc 69.57%
# iteration 10600, loss 0.791246, val acc 69.57%
# iteration 10700, loss 0.789838, val acc 69.57%
# iteration 10800, loss 0.788429, val acc 69.57%
# iteration 10900, loss 0.787021, val acc 69.57%
# iteration 11000, loss 0.785613, val acc 69.57%
# iteration 11100, loss 0.784204, val acc 69.57%
# iteration 11200, loss 0.782796, val acc 73.91%
# iteration 11300, loss 0.781388, val acc 76.09%
# iteration 11400, loss 0.779980, val acc 76.09%
# iteration 11500, loss 0.778572, val acc 80.43%
# iteration 11600, loss 0.777164, val acc 80.43%
# iteration 11700, loss 0.775757, val acc 80.43%
# iteration 11800, loss 0.774349, val acc 80.43%
# iteration 11900, loss 0.772941, val acc 80.43%
# iteration 12000, loss 0.771533, val acc 80.43%
# iteration 12100, loss 0.770126, val acc 80.43%
# iteration 12200, loss 0.768718, val acc 80.43%
# iteration 12300, loss 0.767311, val acc 82.61%
# iteration 12400, loss 0.765903, val acc 82.61%
# iteration 12500, loss 0.764496, val acc 82.61%
# iteration 12600, loss 0.763089, val acc 82.61%
# iteration 12700, loss 0.761681, val acc 82.61%
# iteration 12800, loss 0.760274, val acc 82.61%
# iteration 12900, loss 0.758867, val acc 82.61%
# iteration 13000, loss 0.757460, val acc 82.61%
# iteration 13100, loss 0.756053, val acc 82.61%
# iteration 13200, loss 0.754646, val acc 84.78%
# iteration 13300, loss 0.753239, val acc 84.78%
# iteration 13400, loss 0.751832, val acc 82.61%
# iteration 13500, loss 0.750425, val acc 82.61%
# iteration 13600, loss 0.749018, val acc 82.61%
# iteration 13700, loss 0.747612, val acc 82.61%
# iteration 13800, loss 0.746210, val acc 82.61%
# iteration 13900, loss 0.744808, val acc 82.61%
# iteration 14000, loss 0.743406, val acc 82.61%
# iteration 14100, loss 0.742004, val acc 82.61%
# iteration 14200, loss 0.740603, val acc 82.61%
# iteration 14300, loss 0.739201, val acc 84.78%
# iteration 14400, loss 0.737799, val acc 84.78%
# iteration 14500, loss 0.736401, val acc 84.78%
# iteration 14600, loss 0.735011, val acc 84.78%
# iteration 14700, loss 0.733621, val acc 84.78%
# iteration 14800, loss 0.732232, val acc 84.78%
# iteration 14900, loss 0.730842, val acc 84.78%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #
# using loss_loss_history and loss_val_history                                     #
####################################################################################

epochs = range(1,num_iters+1)
plt.plot(epochs, loss_history, 'g', label='Training loss')
plt.plot(epochs, loss_val_history, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 1:
# With changing your hyper parameters, find a configuration of hyper parameters that cause your loss to increase after each iteration and then report that configuration in the next cell. Explain why our loss increases?
# Write your answer in ""

# %% [markdown]
# std = "0.0001" <br>
# num_iters = "7000"<br>
# reg_coeff = "80"<br>
# learning_rate = "1e-5"<br>

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 80
learning_rate= 1e-5
from sklearn.metrics import accuracy_score
model = SVM(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
epochs = range(1,num_iters+1)
plt.plot(epochs, loss_history, 'g', label='Training loss')
plt.plot(epochs, loss_val_history, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# iteration 0, loss 1.007605, val acc 58.70%
# iteration 100, loss 0.780585, val acc 69.57%
# iteration 200, loss 0.882289, val acc 76.09%
# iteration 300, loss 0.538348, val acc 78.26%
# iteration 400, loss 0.493800, val acc 78.26%
# iteration 500, loss 0.473479, val acc 78.26%
# iteration 600, loss 0.465251, val acc 78.26%
# iteration 700, loss 0.431715, val acc 82.61%
# iteration 800, loss 0.513279, val acc 78.26%
# iteration 900, loss 0.459452, val acc 78.26%
# iteration 1000, loss 0.418525, val acc 82.61%
# iteration 1100, loss 0.445705, val acc 82.61%
# iteration 1200, loss 0.450960, val acc 80.43%
# iteration 1300, loss 0.395080, val acc 84.78%
# iteration 1400, loss 0.459391, val acc 78.26%
# iteration 1500, loss 0.399020, val acc 84.78%
# iteration 1600, loss 0.556378, val acc 80.43%
# iteration 1700, loss 0.442246, val acc 82.61%
# iteration 1800, loss 0.443719, val acc 82.61%
# iteration 1900, loss 0.384515, val acc 84.78%
# iteration 2000, loss 0.492879, val acc 78.26%
# iteration 2100, loss 0.449153, val acc 82.61%
# iteration 2200, loss 0.411637, val acc 82.61%
# iteration 2300, loss 0.482120, val acc 78.26%
# iteration 2400, loss 0.405673, val acc 82.61%
# iteration 2500, loss 0.483248, val acc 78.26%
# iteration 2600, loss 0.369422, val acc 84.78%
# iteration 2700, loss 0.512591, val acc 78.26%
# iteration 2800, loss 0.448864, val acc 82.61%
# iteration 2900, loss 0.406942, val acc 82.61%
# iteration 3000, loss 0.479649, val acc 78.26%
# iteration 3100, loss 0.438999, val acc 82.61%
# iteration 3200, loss 0.439814, val acc 82.61%
# iteration 3300, loss 0.444191, val acc 82.61%
# iteration 3400, loss 0.444259, val acc 82.61%
# iteration 3500, loss 0.437553, val acc 82.61%
# iteration 3600, loss 0.442403, val acc 82.61%
# iteration 3700, loss 0.440490, val acc 82.61%
# iteration 3800, loss 0.440318, val acc 82.61%
# iteration 3900, loss 0.440453, val acc 82.61%
# iteration 4000, loss 0.444939, val acc 82.61%
# iteration 4100, loss 0.407279, val acc 82.61%
# iteration 4200, loss 0.490509, val acc 78.26%
# iteration 4300, loss 0.362044, val acc 84.78%
# iteration 4400, loss 0.408062, val acc 82.61%
# iteration 4500, loss 0.479920, val acc 78.26%
# iteration 4600, loss 0.372880, val acc 84.78%
# iteration 4700, loss 0.571229, val acc 80.43%
# iteration 4800, loss 0.478278, val acc 78.26%
# iteration 4900, loss 0.404919, val acc 82.61%
# iteration 5000, loss 0.467122, val acc 78.26%
# iteration 5100, loss 0.440509, val acc 82.61%
# iteration 5200, loss 0.440798, val acc 82.61%
# iteration 5300, loss 0.440753, val acc 82.61%
# iteration 5400, loss 0.441622, val acc 82.61%
# iteration 5500, loss 0.378143, val acc 84.78%
# iteration 5600, loss 0.486102, val acc 78.26%
# iteration 5700, loss 0.361177, val acc 84.78%
# iteration 5800, loss 0.541941, val acc 80.43%
# iteration 5900, loss 0.475717, val acc 78.26%
# iteration 6000, loss 0.384756, val acc 84.78%
# iteration 6100, loss 0.546677, val acc 80.43%
# iteration 6200, loss 0.479116, val acc 78.26%
# iteration 6300, loss 0.404983, val acc 82.61%
# iteration 6400, loss 0.474513, val acc 78.26%
# iteration 6500, loss 0.439797, val acc 82.61%
# iteration 6600, loss 0.440722, val acc 82.61%
# iteration 6700, loss 0.440684, val acc 82.61%
# iteration 6800, loss 0.440757, val acc 82.61%
# iteration 6900, loss 0.439677, val acc 82.61%
# iteration 7000, loss 0.440101, val acc 82.61%
# iteration 7100, loss 0.440391, val acc 82.61%
# iteration 7200, loss 0.441536, val acc 82.61%
# iteration 7300, loss 0.440288, val acc 82.61%
# iteration 7400, loss 0.440438, val acc 82.61%
# iteration 7500, loss 0.440388, val acc 82.61%
# iteration 7600, loss 0.406163, val acc 82.61%
# iteration 7700, loss 0.486378, val acc 78.26%
# iteration 7800, loss 0.362339, val acc 84.78%
# iteration 7900, loss 0.530312, val acc 78.26%
# iteration 8000, loss 0.432325, val acc 82.61%
# iteration 8100, loss 0.410541, val acc 82.61%
# iteration 8200, loss 0.478950, val acc 78.26%
# iteration 8300, loss 0.378842, val acc 84.78%
# iteration 8400, loss 0.622166, val acc 80.43%
# iteration 8500, loss 0.485324, val acc 78.26%
# iteration 8600, loss 0.406093, val acc 82.61%
# iteration 8700, loss 0.484614, val acc 78.26%
# iteration 8800, loss 0.440385, val acc 82.61%
# iteration 8900, loss 0.444034, val acc 82.61%
# iteration 9000, loss 0.444110, val acc 82.61%
# iteration 9100, loss 0.444180, val acc 82.61%
# iteration 9200, loss 0.444456, val acc 82.61%
# iteration 9300, loss 0.440907, val acc 82.61%
# iteration 9400, loss 0.443099, val acc 82.61%
# iteration 9500, loss 0.441731, val acc 82.61%
# iteration 9600, loss 0.442499, val acc 82.61%
# iteration 9700, loss 0.442647, val acc 82.61%
# iteration 9800, loss 0.410393, val acc 82.61%
# iteration 9900, loss 0.482816, val acc 78.26%
# iteration 10000, loss 0.393970, val acc 84.78%
# iteration 10100, loss 0.595608, val acc 80.43%
# iteration 10200, loss 0.477242, val acc 78.26%
# iteration 10300, loss 0.405085, val acc 82.61%
# iteration 10400, loss 0.513962, val acc 78.26%
# iteration 10500, loss 0.373735, val acc 84.78%
# iteration 10600, loss 0.519959, val acc 78.26%
# iteration 10700, loss 0.460510, val acc 78.26%
# iteration 10800, loss 0.407624, val acc 82.61%
# iteration 10900, loss 0.461959, val acc 78.26%
# iteration 11000, loss 0.439196, val acc 82.61%
# iteration 11100, loss 0.443940, val acc 82.61%
# iteration 11200, loss 0.440666, val acc 82.61%
# iteration 11300, loss 0.440746, val acc 82.61%
# iteration 11400, loss 0.436755, val acc 82.61%
# iteration 11500, loss 0.541481, val acc 80.43%
# iteration 11600, loss 0.381729, val acc 84.78%
# iteration 11700, loss 0.412136, val acc 82.61%
# iteration 11800, loss 0.479128, val acc 78.26%
# iteration 11900, loss 0.409598, val acc 82.61%
# iteration 12000, loss 0.480798, val acc 78.26%
# iteration 12100, loss 0.440269, val acc 82.61%
# iteration 12200, loss 0.440357, val acc 82.61%
# iteration 12300, loss 0.440438, val acc 82.61%
# iteration 12400, loss 0.442509, val acc 82.61%
# iteration 12500, loss 0.417867, val acc 82.61%
# iteration 12600, loss 0.478481, val acc 78.26%
# iteration 12700, loss 0.405245, val acc 82.61%
# iteration 12800, loss 0.480885, val acc 78.26%
# iteration 12900, loss 0.375865, val acc 84.78%
# iteration 13000, loss 0.525555, val acc 78.26%
# iteration 13100, loss 0.384939, val acc 84.78%
# iteration 13200, loss 0.539683, val acc 78.26%
# iteration 13300, loss 0.438904, val acc 82.61%
# iteration 13400, loss 0.408597, val acc 82.61%
# iteration 13500, loss 0.478795, val acc 78.26%
# iteration 13600, loss 0.440114, val acc 82.61%
# iteration 13700, loss 0.443894, val acc 82.61%
# iteration 13800, loss 0.440857, val acc 82.61%
# iteration 13900, loss 0.440931, val acc 82.61%
# iteration 14000, loss 0.369317, val acc 84.78%
# iteration 14100, loss 0.521177, val acc 78.26%
# iteration 14200, loss 0.362397, val acc 84.78%
# iteration 14300, loss 0.556648, val acc 80.43%
# iteration 14400, loss 0.477450, val acc 78.26%
# iteration 14500, loss 0.386181, val acc 84.78%
# iteration 14600, loss 0.483681, val acc 78.26%
# iteration 14700, loss 0.385814, val acc 84.78%
# iteration 14800, loss 0.533531, val acc 78.26%
# iteration 14900, loss 0.439331, val acc 82.61%

# %% [markdown]
# ### Question 2:
# In this cell please explain the reason of this event<br>
# Answer:
# <div dir='rtl'>
#      تغییرات اساسی بالا reg_coef و learning_rate می‌باشد. علت  پایین بالا رفتن آن چون lr آن زیاد شده هنگام همگرا شدن در یک لوپ گیر می‌کند و  دچار بالا پایین‌هایی می‌شود. از  طرفی چون reg_coef  آن بالا رفته تاثیر regulizer آن بیشتر می‌شود و مدلمان ساده‌تر می‌شود و این  خود شدت fluctuation
#    را زیادتر می‌کند
# . چون  امکان دسته‌بندی اشتباه بیشتری دارد پس موجب تشدید آن می‌شود.
# </div>

# %%
val_preds =  model.predict(X_test)
###########################################################################################
# TODO: find the Confusion Matrix between val_preds and real labels (y_test) for test data#
# then report the accuracy of the model.                                                  #
# you are not allowed to use any premade function for accuracy and confusion matrix       #
###########################################################################################

def confusion_matrix(predicted, real):
    labels = dict()
    n = 0
    for i in predicted:
        if not labels.__contains__(i):
            labels[i] = n
            n += 1
    for i in real:
        if not labels.__contains__(i):
            labels[i] = n
            n += 1
    cm = [[0 for _ in range(len(labels))] for _ in range(len(labels))]
    # tn, fp, fn, tp
    for i in range(len(predicted)):
        cm[labels[real[i]]][labels[predicted[i]]] += 1
    print("Confusion Matrix: ", cm)
    return cm
y_pred = model.predict(X_test) 
cm = confusion_matrix(y_pred,y_test)
print("acc:",100*(cm[0][0]+cm[1][1])/len(y_test))
 

###########################################################################################
#                                END OF YOUR EXPLANATION                                  #
###########################################################################################
# Out:
# Confusion Matrix:  [[44, 0], [70, 0]]
# acc: 38.59649122807018

# %% [markdown]
# In the next part, we sample from training data with certain size (batch size) instead of using all the training data in each iteration, and train our model on batch data:

# %%
std = 0.0001
batch_size = 200
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8
model = SVM(n_features=X_train.shape[1], std= std )

# %%
loss_history = []
loss_val_history = []
for it in range(num_iters):
    X_batch = None
    y_batch = None
    ################################################################################
    # TODO: Sample batch_size elements from the training data and their            #
    # corresponding labels to use in this round of gradient descent.               #
    # Store the data in X_batch and their corresponding labels in                  #
    # y_batch; after sampling X_batch should have shape (batch_size, n_features)   #
    # and y_batch should have shape (batch_size,)                                  #
    #                                                                              #
    # Hint: Use np.random.choice to generate indices. Sampling with                #
    # replacement is faster than sampling without replacement.                     #
    ################################################################################

    choices = np.random.choice(len(X_train), batch_size, replace=True)
    X_batch = X_train[choices]
    y_batch = y_train[choices]

    ################################################################################
    #                                 END OF YOUR CODE                             #
    ################################################################################
    loss = model.loss(X_batch, y_batch, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracy_score(y_val,val_preds) * 100))
    model.update_weights(X_batch, y_batch, learning_rate , reg_coeff)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.023313, val acc 58.70%
# iteration 100, loss 0.960102, val acc 41.30%
# iteration 200, loss 0.997968, val acc 41.30%
# iteration 300, loss 0.951481, val acc 41.30%
# iteration 400, loss 0.899668, val acc 41.30%
# iteration 500, loss 0.883795, val acc 41.30%
# iteration 600, loss 0.957462, val acc 41.30%
# iteration 700, loss 0.972354, val acc 41.30%
# iteration 800, loss 0.977830, val acc 41.30%
# iteration 900, loss 0.946118, val acc 41.30%
# iteration 1000, loss 0.913537, val acc 41.30%
# iteration 1100, loss 0.896147, val acc 41.30%
# iteration 1200, loss 0.865911, val acc 41.30%
# iteration 1300, loss 0.884569, val acc 41.30%
# iteration 1400, loss 0.962985, val acc 41.30%
# iteration 1500, loss 0.959461, val acc 41.30%
# iteration 1600, loss 0.856335, val acc 41.30%
# iteration 1700, loss 0.908522, val acc 41.30%
# iteration 1800, loss 0.984959, val acc 41.30%
# iteration 1900, loss 0.924658, val acc 41.30%
# iteration 2000, loss 0.929462, val acc 41.30%
# iteration 2100, loss 0.960248, val acc 41.30%
# iteration 2200, loss 0.945515, val acc 41.30%
# iteration 2300, loss 0.873681, val acc 41.30%
# iteration 2400, loss 0.903723, val acc 41.30%
# iteration 2500, loss 0.926648, val acc 41.30%
# iteration 2600, loss 0.889723, val acc 41.30%
# iteration 2700, loss 0.893804, val acc 41.30%
# iteration 2800, loss 0.949178, val acc 41.30%
# iteration 2900, loss 0.889514, val acc 41.30%
# iteration 3000, loss 0.883368, val acc 41.30%
# iteration 3100, loss 0.897749, val acc 41.30%
# iteration 3200, loss 0.932807, val acc 41.30%
# iteration 3300, loss 0.952614, val acc 41.30%
# iteration 3400, loss 0.940576, val acc 41.30%
# iteration 3500, loss 0.868841, val acc 41.30%
# iteration 3600, loss 0.884127, val acc 41.30%
# iteration 3700, loss 0.892493, val acc 41.30%
# iteration 3800, loss 0.872711, val acc 41.30%
# iteration 3900, loss 0.884203, val acc 41.30%
# iteration 4000, loss 0.874288, val acc 41.30%
# iteration 4100, loss 0.913145, val acc 41.30%
# iteration 4200, loss 0.877795, val acc 41.30%
# iteration 4300, loss 0.886214, val acc 41.30%
# iteration 4400, loss 0.863769, val acc 41.30%
# iteration 4500, loss 0.822521, val acc 41.30%
# iteration 4600, loss 0.906884, val acc 41.30%
# iteration 4700, loss 0.815777, val acc 41.30%
# iteration 4800, loss 0.866155, val acc 41.30%
# iteration 4900, loss 0.881444, val acc 41.30%
# iteration 5000, loss 0.915440, val acc 41.30%
# iteration 5100, loss 0.873116, val acc 41.30%
# iteration 5200, loss 0.875092, val acc 41.30%
# iteration 5300, loss 0.876638, val acc 41.30%
# iteration 5400, loss 0.853550, val acc 41.30%
# iteration 5500, loss 0.849208, val acc 41.30%
# iteration 5600, loss 0.842976, val acc 41.30%
# iteration 5700, loss 0.863856, val acc 41.30%
# iteration 5800, loss 0.877923, val acc 41.30%
# iteration 5900, loss 0.883411, val acc 41.30%
# iteration 6000, loss 0.854672, val acc 41.30%
# iteration 6100, loss 0.852384, val acc 41.30%
# iteration 6200, loss 0.848533, val acc 41.30%
# iteration 6300, loss 0.868811, val acc 41.30%
# iteration 6400, loss 0.885504, val acc 41.30%
# iteration 6500, loss 0.809129, val acc 41.30%
# iteration 6600, loss 0.830908, val acc 41.30%
# iteration 6700, loss 0.837556, val acc 41.30%
# iteration 6800, loss 0.833921, val acc 41.30%
# iteration 6900, loss 0.843030, val acc 41.30%
# iteration 7000, loss 0.851598, val acc 43.48%
# iteration 7100, loss 0.868344, val acc 43.48%
# iteration 7200, loss 0.867041, val acc 43.48%
# iteration 7300, loss 0.822330, val acc 45.65%
# iteration 7400, loss 0.882001, val acc 43.48%
# iteration 7500, loss 0.853055, val acc 45.65%
# iteration 7600, loss 0.778572, val acc 50.00%
# iteration 7700, loss 0.798725, val acc 50.00%
# iteration 7800, loss 0.829488, val acc 50.00%
# iteration 7900, loss 0.869360, val acc 52.17%
# iteration 8000, loss 0.817268, val acc 54.35%
# iteration 8100, loss 0.835525, val acc 56.52%
# iteration 8200, loss 0.852040, val acc 58.70%
# iteration 8300, loss 0.836484, val acc 58.70%
# iteration 8400, loss 0.825077, val acc 58.70%
# iteration 8500, loss 0.807803, val acc 63.04%
# iteration 8600, loss 0.819901, val acc 63.04%
# iteration 8700, loss 0.814106, val acc 65.22%
# iteration 8800, loss 0.818484, val acc 65.22%
# iteration 8900, loss 0.827434, val acc 65.22%
# iteration 9000, loss 0.814362, val acc 65.22%
# iteration 9100, loss 0.809328, val acc 65.22%
# iteration 9200, loss 0.844266, val acc 65.22%
# iteration 9300, loss 0.817075, val acc 71.74%
# iteration 9400, loss 0.856258, val acc 71.74%
# iteration 9500, loss 0.792864, val acc 71.74%
# iteration 9600, loss 0.810651, val acc 71.74%
# iteration 9700, loss 0.793636, val acc 71.74%
# iteration 9800, loss 0.806598, val acc 73.91%
# iteration 9900, loss 0.805935, val acc 69.57%
# iteration 10000, loss 0.795388, val acc 71.74%
# iteration 10100, loss 0.801644, val acc 71.74%
# iteration 10200, loss 0.797193, val acc 71.74%
# iteration 10300, loss 0.786789, val acc 69.57%
# iteration 10400, loss 0.801340, val acc 69.57%
# iteration 10500, loss 0.797340, val acc 69.57%
# iteration 10600, loss 0.766253, val acc 69.57%
# iteration 10700, loss 0.783544, val acc 69.57%
# iteration 10800, loss 0.777897, val acc 69.57%
# iteration 10900, loss 0.801351, val acc 69.57%
# iteration 11000, loss 0.840787, val acc 76.09%
# iteration 11100, loss 0.739963, val acc 76.09%
# iteration 11200, loss 0.768112, val acc 76.09%
# iteration 11300, loss 0.817699, val acc 80.43%
# iteration 11400, loss 0.759190, val acc 76.09%
# iteration 11500, loss 0.798819, val acc 80.43%
# iteration 11600, loss 0.777789, val acc 80.43%
# iteration 11700, loss 0.778131, val acc 80.43%
# iteration 11800, loss 0.790222, val acc 80.43%
# iteration 11900, loss 0.792653, val acc 80.43%
# iteration 12000, loss 0.767667, val acc 82.61%
# iteration 12100, loss 0.767096, val acc 82.61%
# iteration 12200, loss 0.773957, val acc 82.61%
# iteration 12300, loss 0.771758, val acc 82.61%
# iteration 12400, loss 0.719600, val acc 82.61%
# iteration 12500, loss 0.795687, val acc 82.61%
# iteration 12600, loss 0.781969, val acc 82.61%
# iteration 12700, loss 0.724938, val acc 82.61%
# iteration 12800, loss 0.755720, val acc 82.61%
# iteration 12900, loss 0.770234, val acc 82.61%
# iteration 13000, loss 0.776262, val acc 82.61%
# iteration 13100, loss 0.747572, val acc 84.78%
# iteration 13200, loss 0.795244, val acc 82.61%
# iteration 13300, loss 0.736081, val acc 84.78%
# iteration 13400, loss 0.772065, val acc 84.78%
# iteration 13500, loss 0.708969, val acc 84.78%
# iteration 13600, loss 0.731307, val acc 82.61%
# iteration 13700, loss 0.740242, val acc 82.61%
# iteration 13800, loss 0.734102, val acc 82.61%
# iteration 13900, loss 0.769983, val acc 82.61%
# iteration 14000, loss 0.717324, val acc 82.61%
# iteration 14100, loss 0.739990, val acc 82.61%
# iteration 14200, loss 0.744369, val acc 84.78%
# iteration 14300, loss 0.750704, val acc 84.78%
# iteration 14400, loss 0.768551, val acc 84.78%
# iteration 14500, loss 0.697540, val acc 84.78%
# iteration 14600, loss 0.739017, val acc 84.78%
# iteration 14700, loss 0.744847, val acc 84.78%
# iteration 14800, loss 0.748911, val acc 84.78%
# iteration 14900, loss 0.724806, val acc 84.78%

# %%
####################################################################################
# TODO: using matplotlib.pyplot package plot the training loss and validation loss #

####################################################################################

epochs = range(1,num_iters+1)
plt.plot(epochs, loss_history, 'g', label='Training loss')
plt.plot(epochs, loss_val_history, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

####################################################################################
#                                 END OF YOUR CODE                                 #
####################################################################################

# %% [markdown]
# ### Question 3:
# Explain why we see fluctuation in this plot?<br>
# Answer:<div dir='rtl'>
# چون ما در هر مرحله کل داده را نمی‌بینیم و  نمونه‌گیری می‌کنیم٬ این  باعث می‌شود با توجه به نمونه‌گیری  در هر مرحله ‌دچار نوساناتی شویم ولی در طولانی مدت اثر آن و بهتر شدن ‌validation loss  را می‌بینیم.
# </div>

# %% [markdown]
# # Problem 2. Perceptron

# %% [markdown]
# By now, you should know how to use and how to implement SVM from scratch.
# In fact, for perceptron we can use premade functions as below:

# %%
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
clf = Perceptron(tol=1e-3, random_state=0)
clf.fit(X_train, y_train)
val_preds = clf.predict(X_test)
print(confusion_matrix(y_test,val_preds,[1,-1]))
print('test acc %.2f%%' % (accuracy_score(y_test,val_preds) * 100))
# Out:
# [[37 33]
#  [ 0 44]]
# test acc 71.05%

# %% [markdown]
# ### Question 4:
# It is time for you to write your own code instead of completing some parts of a premade code.<br>
# So you can not use any premade functions like the previous cell.
# Write your code in the end of this .ipynb file <br>
# You should make your model and use that to build these outputs:<br>
# 1- Report loss of training and accuracy of validation data on each epoch of training process.<br>
# 2- You are allowed to use any normalization approach if need be.<br>
# 3- Plot your training and validation loss vs number of iterations in one plot.<br>
# 4- Finally print your confusion matrix and accuracy for your testing set.<br>
# With changing your hyperparameters try to get a good and reasonable accuracy and confusion matrix on testing set (similar to the accuracy when we used the package).

# %%
import numpy as np
class Perceptron:
    def __init__(self, n_features: int, std: float):

        self.n_features = n_features
        mu, sigma = 0, 0.1 
        self.W = np.random.normal(0, std , n_features)

    def loss(self, X: np.ndarray, y: np.ndarray, reg_coeff: float):    
        loss = 0.0
        scores = np.dot(X, self.W)
        scores = np.multiply(scores,y)
        loss = sum(np.maximum(0, 1-scores))/len(scores)
        return loss
        
    def update_weights(self,  X: np.ndarray, y: np.ndarray, learning_rate: float):

        
        for i in range(len(y)):
            if 1 - np.dot(X[i],self.W)*y[i] > 0:
                self.W += learning_rate*y[i]*X[i]/(X.shape[0])

    def predict(self, X):
        y_pred = None


        y_pred = []
        for i in range(len(X)):
            r = np.dot(X[i],self.W)
            if r > 0:
                y_pred.append(1)
            else:
                y_pred.append(-1)
        return y_pred

# %%
std = 0.0001
num_iters = 15000
reg_coeff = 20
learning_rate=1e-8

# %%
def accuracyScore(y,preds):
    t = 0
    for i in range(len(y)):
        if y[i] == preds[i]:
            t += 1
    return t/len(y)

# %%
model = Perceptron(n_features=X_train.shape[1], std= std )
loss_history = []
loss_val_history = []
for it in range(num_iters):
    loss = model.loss(X_train, y_train, reg_coeff)
    loss_val = model.loss(X_val, y_val, reg_coeff)
    if it % 100 == 0:
        val_preds =  model.predict(X_val)
        print('iteration %d, loss %f, val acc %.2f%%' % (it, loss,  accuracyScore(y_val,val_preds) * 100))
    model.update_weights(X_train, y_train, learning_rate)
    loss_history.append(loss)
    loss_val_history.append(loss_val)
# Out:
# iteration 0, loss 1.025173, val acc 58.70%
# iteration 100, loss 0.995881, val acc 41.30%
# iteration 200, loss 0.966634, val acc 41.30%
# iteration 300, loss 0.949202, val acc 41.30%
# iteration 400, loss 0.942476, val acc 41.30%
# iteration 500, loss 0.939996, val acc 41.30%
# iteration 600, loss 0.938306, val acc 41.30%
# iteration 700, loss 0.936650, val acc 41.30%
# iteration 800, loss 0.934993, val acc 41.30%
# iteration 900, loss 0.933336, val acc 41.30%
# iteration 1000, loss 0.931680, val acc 41.30%
# iteration 1100, loss 0.930023, val acc 41.30%
# iteration 1200, loss 0.928367, val acc 41.30%
# iteration 1300, loss 0.926710, val acc 41.30%
# iteration 1400, loss 0.925061, val acc 41.30%
# iteration 1500, loss 0.923413, val acc 41.30%
# iteration 1600, loss 0.921765, val acc 41.30%
# iteration 1700, loss 0.920117, val acc 41.30%
# iteration 1800, loss 0.918469, val acc 41.30%
# iteration 1900, loss 0.916821, val acc 41.30%
# iteration 2000, loss 0.915173, val acc 41.30%
# iteration 2100, loss 0.913556, val acc 41.30%
# iteration 2200, loss 0.911962, val acc 41.30%
# iteration 2300, loss 0.910406, val acc 41.30%
# iteration 2400, loss 0.908859, val acc 41.30%
# iteration 2500, loss 0.907320, val acc 41.30%
# iteration 2600, loss 0.905781, val acc 41.30%
# iteration 2700, loss 0.904242, val acc 41.30%
# iteration 2800, loss 0.902703, val acc 41.30%
# iteration 2900, loss 0.901174, val acc 41.30%
# iteration 3000, loss 0.899683, val acc 41.30%
# iteration 3100, loss 0.898192, val acc 41.30%
# iteration 3200, loss 0.896702, val acc 41.30%
# iteration 3300, loss 0.895223, val acc 41.30%
# iteration 3400, loss 0.893772, val acc 41.30%
# iteration 3500, loss 0.892322, val acc 41.30%
# iteration 3600, loss 0.890871, val acc 41.30%
# iteration 3700, loss 0.889420, val acc 41.30%
# iteration 3800, loss 0.887970, val acc 41.30%
# iteration 3900, loss 0.886519, val acc 41.30%
# iteration 4000, loss 0.885069, val acc 41.30%
# iteration 4100, loss 0.883618, val acc 41.30%
# iteration 4200, loss 0.882167, val acc 41.30%
# iteration 4300, loss 0.880717, val acc 41.30%
# iteration 4400, loss 0.879271, val acc 41.30%
# iteration 4500, loss 0.877826, val acc 41.30%
# iteration 4600, loss 0.876381, val acc 41.30%
# iteration 4700, loss 0.874936, val acc 41.30%
# iteration 4800, loss 0.873491, val acc 41.30%
# iteration 4900, loss 0.872046, val acc 41.30%
# iteration 5000, loss 0.870601, val acc 41.30%
# iteration 5100, loss 0.869163, val acc 41.30%
# iteration 5200, loss 0.867736, val acc 41.30%
# iteration 5300, loss 0.866309, val acc 41.30%
# iteration 5400, loss 0.864881, val acc 41.30%
# iteration 5500, loss 0.863453, val acc 41.30%
# iteration 5600, loss 0.862026, val acc 41.30%
# iteration 5700, loss 0.860598, val acc 41.30%
# iteration 5800, loss 0.859170, val acc 41.30%
# iteration 5900, loss 0.857743, val acc 41.30%
# iteration 6000, loss 0.856315, val acc 41.30%
# iteration 6100, loss 0.854888, val acc 41.30%
# iteration 6200, loss 0.853460, val acc 41.30%
# iteration 6300, loss 0.852033, val acc 41.30%
# iteration 6400, loss 0.850605, val acc 41.30%
# iteration 6500, loss 0.849178, val acc 41.30%
# iteration 6600, loss 0.847750, val acc 41.30%
# iteration 6700, loss 0.846322, val acc 41.30%
# iteration 6800, loss 0.844895, val acc 41.30%
# iteration 6900, loss 0.843467, val acc 41.30%
# iteration 7000, loss 0.842040, val acc 43.48%
# iteration 7100, loss 0.840612, val acc 43.48%
# iteration 7200, loss 0.839192, val acc 45.65%
# iteration 7300, loss 0.837773, val acc 45.65%
# iteration 7400, loss 0.836353, val acc 45.65%
# iteration 7500, loss 0.834934, val acc 50.00%
# iteration 7600, loss 0.833515, val acc 50.00%
# iteration 7700, loss 0.832095, val acc 50.00%
# iteration 7800, loss 0.830676, val acc 50.00%
# iteration 7900, loss 0.829256, val acc 52.17%
# iteration 8000, loss 0.827837, val acc 56.52%
# iteration 8100, loss 0.826417, val acc 58.70%
# iteration 8200, loss 0.824998, val acc 58.70%
# iteration 8300, loss 0.823578, val acc 63.04%
# iteration 8400, loss 0.822159, val acc 65.22%
# iteration 8500, loss 0.820740, val acc 65.22%
# iteration 8600, loss 0.819320, val acc 65.22%
# iteration 8700, loss 0.817901, val acc 65.22%
# iteration 8800, loss 0.816481, val acc 67.39%
# iteration 8900, loss 0.815062, val acc 71.74%
# iteration 9000, loss 0.813645, val acc 71.74%
# iteration 9100, loss 0.812230, val acc 71.74%
# iteration 9200, loss 0.810816, val acc 71.74%
# iteration 9300, loss 0.809401, val acc 71.74%
# iteration 9400, loss 0.807987, val acc 71.74%
# iteration 9500, loss 0.806573, val acc 71.74%
# iteration 9600, loss 0.805158, val acc 71.74%
# iteration 9700, loss 0.803744, val acc 73.91%
# iteration 9800, loss 0.802329, val acc 73.91%
# iteration 9900, loss 0.800915, val acc 71.74%
# iteration 10000, loss 0.799501, val acc 71.74%
# iteration 10100, loss 0.798086, val acc 71.74%
# iteration 10200, loss 0.796672, val acc 69.57%
# iteration 10300, loss 0.795258, val acc 69.57%
# iteration 10400, loss 0.793843, val acc 69.57%
# iteration 10500, loss 0.792429, val acc 69.57%
# iteration 10600, loss 0.791014, val acc 69.57%
# iteration 10700, loss 0.789600, val acc 69.57%
# iteration 10800, loss 0.788186, val acc 69.57%
# iteration 10900, loss 0.786771, val acc 69.57%
# iteration 11000, loss 0.785357, val acc 69.57%
# iteration 11100, loss 0.783943, val acc 73.91%
# iteration 11200, loss 0.782528, val acc 76.09%
# iteration 11300, loss 0.781114, val acc 76.09%
# iteration 11400, loss 0.779699, val acc 76.09%
# iteration 11500, loss 0.778285, val acc 78.26%
# iteration 11600, loss 0.776871, val acc 80.43%
# iteration 11700, loss 0.775456, val acc 80.43%
# iteration 11800, loss 0.774042, val acc 80.43%
# iteration 11900, loss 0.772628, val acc 80.43%
# iteration 12000, loss 0.771213, val acc 80.43%
# iteration 12100, loss 0.769799, val acc 80.43%
# iteration 12200, loss 0.768384, val acc 80.43%
# iteration 12300, loss 0.766970, val acc 82.61%
# iteration 12400, loss 0.765556, val acc 82.61%
# iteration 12500, loss 0.764141, val acc 82.61%
# iteration 12600, loss 0.762727, val acc 82.61%
# iteration 12700, loss 0.761312, val acc 82.61%
# iteration 12800, loss 0.759898, val acc 82.61%
# iteration 12900, loss 0.758484, val acc 82.61%
# iteration 13000, loss 0.757069, val acc 82.61%
# iteration 13100, loss 0.755655, val acc 82.61%
# iteration 13200, loss 0.754241, val acc 84.78%
# iteration 13300, loss 0.752826, val acc 84.78%
# iteration 13400, loss 0.751412, val acc 84.78%
# iteration 13500, loss 0.749997, val acc 84.78%
# iteration 13600, loss 0.748583, val acc 82.61%
# iteration 13700, loss 0.747169, val acc 82.61%
# iteration 13800, loss 0.745754, val acc 82.61%
# iteration 13900, loss 0.744340, val acc 84.78%
# iteration 14000, loss 0.742926, val acc 84.78%
# iteration 14100, loss 0.741512, val acc 84.78%
# iteration 14200, loss 0.740102, val acc 84.78%
# iteration 14300, loss 0.738692, val acc 84.78%
# iteration 14400, loss 0.737283, val acc 84.78%
# iteration 14500, loss 0.735873, val acc 84.78%
# iteration 14600, loss 0.734463, val acc 84.78%
# iteration 14700, loss 0.733054, val acc 84.78%
# iteration 14800, loss 0.731644, val acc 84.78%
# iteration 14900, loss 0.730234, val acc 84.78%

# %%
epochs = range(1,num_iters+1)
plt.plot(epochs, loss_history, 'g', label='Training loss')
plt.plot(epochs, loss_val_history, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
val_preds =  model.predict(X_test)
###########################################################################################
# TODO: find the Confusion Matrix between val_preds and real labels (y_test) for test data#
# then report the accuracy of the model.                                                  #
# you are not allowed to use any premade function for accuracy and confusion matrix       #
###########################################################################################

def confusion_matrix(predicted, real):
    labels = dict()
    n = 0
    for i in predicted:
        if not labels.__contains__(i):
            labels[i] = n
            n += 1
    for i in real:
        if not labels.__contains__(i):
            labels[i] = n
            n += 1
    cm = [[0 for _ in range(len(labels))] for _ in range(len(labels))]
    # tn, fp, fn, tp
    for i in range(len(predicted)):
        cm[labels[real[i]]][labels[predicted[i]]] += 1
    print("Confusion Matrix: ", cm)
    return cm
y_pred = model.predict(X_test) 
cm = confusion_matrix(y_pred,y_test)
print("acc:",100*(cm[0][0]+cm[1][1])/len(y_test))
 

###########################################################################################
#                                END OF YOUR EXPLANATION                                  #
###########################################################################################
# Out:
# Confusion Matrix:  [[67, 3], [8, 36]]
# acc: 90.35087719298245
